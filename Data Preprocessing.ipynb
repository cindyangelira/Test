# %% [markdown]
# # DEPENDENCIES

# %%
import numpy as np
import pandas as pd
import pandas_gbq
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (20, 12)

import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyoff
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

# %% [markdown]
# ### Connect to BQ Kraken Database

# %%
import os 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/Users/asani/Downloads/octopus-data-prod-294206-8028c6b220ce.json'

# %%
project_id = 'octopus-data-prod-294206'
sql = """
SELECT *
FROM `octopus-data-prod-294206.KRAKEN_temp_view.customer_orders`
"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
# Out:
# Downloading: 100%|██████████|

# %%
df.head()
# Out:
#                                order_id system                  timestamp  \
# 0  db6a35c0-c64e-4864-87a8-6ec5144340b4     V2 2021-08-22 20:14:51.507747
# 1  7226a173-2d68-4590-bfed-083f972eb185     V2 2021-06-15 09:10:49.214557
# 2  b6193928-1782-47e4-a3dd-5457b5f4e6e9     V2 2021-05-19 20:50:04.808810
# 3  d60857d5-b189-4344-9fb4-de33160d181c     V2 2021-08-04 12:55:42.248596
# 4  dbf9a628-23f4-42f3-b739-e7ff25c9c3d7     V2 2021-06-12 08:21:56.350409
#
#   total_quantity  unit amount_per_qty   total_amount    total_weight  user_id  \
# 0   19.000000000  None   33.000000000  155.000000000   865.775000000    67197
# 1   20.000000000  None   12.500000000  250.000000000  5000.000000000    61422
# 2   20.000000000  None   12.500000000  250.000000000  5000.000000000    58766
# 3   16.000000000  None   23.000000000   70.000000000  1454.040000000    46019
# 4    5.000000000  None    8.000000000   40.000000000    75.755000000    64708
#
#    receiver_id  ...  latitude   longitude    country    province     city  \
# 0         1239  ... -6.941175  107.740361  Indonesia  Jawa Barat  Bandung
# 1          783  ... -6.976872  107.668886  Indonesia  Jawa Barat  Bandung
# 2          796  ... -6.976072  107.655083  Indonesia  Jawa Barat  Bandung
# 3          818  ... -6.976277  107.655804  Indonesia  Jawa Barat  Bandung
# 4          806  ... -7.008113  107.644134  Indonesia  Jawa Barat  Bandung
#
#                 district         village order_status route_id total_distance
# 0               Cileunyi  Cileunyi Kulon    completed     5353       8.370590
# 1  Kecamatan Bojongsoang        Buahbatu    completed     3501       0.000000
# 2  Kecamatan Bojongsoang        Cipagalo    completed     2020       0.000000
# 3  Kecamatan Bojongsoang        Cipagalo    completed     4997       7.582155
# 4    Kecamatan Baleendah      Manggahang    completed     3388       0.000000
#
# [5 rows x 22 columns]

# %%
# Data info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49717 entries, 0 to 49716
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        49717 non-null  object
#  1   system          49717 non-null  object
#  2   timestamp       49717 non-null  datetime64[ns]
#  3   total_quantity  48963 non-null  object
#  4   unit            4657 non-null   object
#  5   amount_per_qty  48963 non-null  object
#  6   total_amount    48963 non-null  object
#  7   total_weight    48963 non-null  object
#  8   user_id         49717 non-null  Int64
#  9   receiver_id     33725 non-null  Int64
#  10  region_id       49717 non-null  Int64
#  11  region_name     48356 non-null  object
#  12  latitude        49717 non-null  float64
#  13  longitude       49717 non-null  float64
#  14  country         48382 non-null  object
#  15  province        48356 non-null  object
#  16  city            48356 non-null  object
#  17  district        48284 non-null  object
#  18  village         48330 non-null  object
#  19  order_status    49717 non-null  object
#  20  route_id        29353 non-null  Int64
#  21  total_distance  29353 non-null  float64
# dtypes: Int64(4), datetime64[ns](1), float64(3), object(14)
# memory usage: 8.5+ MB

# %%
# Check missing value

df.isnull().sum()
# Out:
# order_id              0
# system                0
# timestamp             0
# total_quantity      754
# unit              45060
# amount_per_qty      754
# total_amount        754
# total_weight        754
# user_id               0
# receiver_id       15992
# region_id             0
# region_name        1361
# latitude              0
# longitude             0
# country            1335
# province           1361
# city               1361
# district           1433
# village            1387
# order_status          0
# route_id          20364
# total_distance    20364
# dtype: int64

# %%
# Check Order Status

df.order_status.value_counts()
# Out:
# completed    37035
# cancelled    12682
# Name: order_status, dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %%
df.loc[:,['total_quantity','total_amount', 'total_weight']].astype('float')
# Out:
#        total_quantity  total_amount  total_weight
# 0                19.0         155.0       865.775
# 1                20.0         250.0      5000.000
# 2                20.0         250.0      5000.000
# 3                16.0          70.0      1454.040
# 4                 5.0          40.0        75.755
# ...               ...           ...           ...
# 49712             3.0        2300.0      3000.000
# 49713             3.0        2275.0      3000.000
# 49714             1.0         800.0      1000.000
# 49715             3.0        1850.0      3000.000
# 49716            35.0       24760.0     33010.000
#
# [49717 rows x 3 columns]

# %%
# Datetime Preprocessing

def date_preprocessing(df):
    df = df.copy().loc[:,['order_id', 'user_id', 'timestamp', 'total_quantity', 'total_amount', 'total_weight', 
         'order_status', 'province', 'city']]
    #df['timestamp'] = pd.to_datetime(df['timestamp'])
    df['day'] = df['timestamp'].dt.day
    df['day_name'] = df['timestamp'].dt.day_name()
    df['month'] = df['timestamp'].dt.month
    df['year'] = df['timestamp'].dt.year
    df['month_year'] = df['timestamp'].dt.to_period('M').astype(str)
    df['total_amount'] = df['total_amount'].astype('float')
    df['total_quantity'] = df['total_quantity'].astype('float')
    df['total_weight'] = df['total_weight'].astype('float')
    return df

# %%
# Convert timestamp to datetime

df = date_preprocessing(df)
df.head()
# Out:
#                                order_id  user_id                  timestamp  \
# 0  db6a35c0-c64e-4864-87a8-6ec5144340b4    67197 2021-08-22 20:14:51.507747
# 1  7226a173-2d68-4590-bfed-083f972eb185    61422 2021-06-15 09:10:49.214557
# 2  b6193928-1782-47e4-a3dd-5457b5f4e6e9    58766 2021-05-19 20:50:04.808810
# 3  d60857d5-b189-4344-9fb4-de33160d181c    46019 2021-08-04 12:55:42.248596
# 4  dbf9a628-23f4-42f3-b739-e7ff25c9c3d7    64708 2021-06-12 08:21:56.350409
#
#    total_quantity  total_amount  total_weight order_status    province  \
# 0            19.0         155.0       865.775    completed  Jawa Barat
# 1            20.0         250.0      5000.000    completed  Jawa Barat
# 2            20.0         250.0      5000.000    completed  Jawa Barat
# 3            16.0          70.0      1454.040    completed  Jawa Barat
# 4             5.0          40.0        75.755    completed  Jawa Barat
#
#       city  day   day_name  month  year month_year
# 0  Bandung   22     Sunday      8  2021    2021-08
# 1  Bandung   15    Tuesday      6  2021    2021-06
# 2  Bandung   19  Wednesday      5  2021    2021-05
# 3  Bandung    4  Wednesday      8  2021    2021-08
# 4  Bandung   12   Saturday      6  2021    2021-06

# %%
# Check Rows that total_quantity, total_amount, and total_weight are NA Based on order_status

order_missing = df[df[['total_quantity', 'total_amount','total_weight']].isna().any(axis=1)]
order_missing.order_status.value_counts()
# Out:
# cancelled    730
# completed     24
# Name: order_status, dtype: int64

# %%
# Check Rows that total_quantity, total_amount, and total_weight are NA Based on order_status

order_missing[order_missing['order_status']=='completed'].head()
# Out:
#                                    order_id  user_id  \
# 2629   633dac7f-d76e-4b25-a2bf-69ac67e7fdc2    73886
# 3916   33784908-0b0d-4d30-91da-84b685bffc84    74219
# 9077   bb90deb0-ed18-4b1d-a667-0e933ad9e425    15744
# 14159  ded041c9-8fc6-4729-ad47-d23f0a69a77f    15744
# 15999  509c5310-fd6f-4808-901a-09bb5e4bb253    75182
#
#                        timestamp  total_quantity  total_amount  total_weight  \
# 2629  2021-08-30 16:14:56.466087             NaN           NaN           NaN
# 3916  2021-09-11 11:09:23.129378             NaN           NaN           NaN
# 9077  2021-08-29 20:50:13.956088             NaN           NaN           NaN
# 14159 2021-08-30 05:00:20.483905             NaN           NaN           NaN
# 15999 2021-10-01 15:37:42.956597             NaN           NaN           NaN
#
#       order_status          province              city  day  day_name  month  \
# 2629     completed        Jawa Barat           Bandung   30    Monday      8
# 3916     completed        Jawa Barat      Kota Bandung   11  Saturday      9
# 9077     completed  Sulawesi Selatan    Kabupaten Gowa   29    Sunday      8
# 14159    completed              Bali  Kabupaten Badung   30    Monday      8
# 15999    completed        Jawa Barat      Kota Bandung    1    Friday     10
#
#        year month_year
# 2629   2021    2021-08
# 3916   2021    2021-09
# 9077   2021    2021-08
# 14159  2021    2021-08
# 15999  2021    2021-10

# %% [markdown]
# * There were 24 completed orders which *total quantity*, *total_amount*, and *total_weight* are missing (N/A).
# * We investigate it on psql backend prod database, the listed order_id is not captured on v2.order_item, so we assume there's bug in backend process.
# * Hence, we'll drop these missing values for now. (Already confirmed by tech and product team)

# %%
# Remove missing values of quantity, amount, and weight

df = df.dropna(subset=['total_quantity', 'total_amount','total_weight'])
df.isnull().sum()
# Out:
# order_id             0
# user_id              0
# timestamp            0
# total_quantity       0
# total_amount         0
# total_weight         0
# order_status         0
# province          1269
# city              1269
# day                  0
# day_name             0
# month                0
# year                 0
# month_year           0
# dtype: int64

# %%
# Filter out cancelled order

df_completed = df[df['order_status']=='completed']
df_completed.head()
# Out:
#                                order_id  user_id                  timestamp  \
# 0  db6a35c0-c64e-4864-87a8-6ec5144340b4    67197 2021-08-22 20:14:51.507747
# 1  7226a173-2d68-4590-bfed-083f972eb185    61422 2021-06-15 09:10:49.214557
# 2  b6193928-1782-47e4-a3dd-5457b5f4e6e9    58766 2021-05-19 20:50:04.808810
# 3  d60857d5-b189-4344-9fb4-de33160d181c    46019 2021-08-04 12:55:42.248596
# 4  dbf9a628-23f4-42f3-b739-e7ff25c9c3d7    64708 2021-06-12 08:21:56.350409
#
#    total_quantity  total_amount  total_weight order_status    province  \
# 0            19.0         155.0       865.775    completed  Jawa Barat
# 1            20.0         250.0      5000.000    completed  Jawa Barat
# 2            20.0         250.0      5000.000    completed  Jawa Barat
# 3            16.0          70.0      1454.040    completed  Jawa Barat
# 4             5.0          40.0        75.755    completed  Jawa Barat
#
#       city  day   day_name  month  year month_year
# 0  Bandung   22     Sunday      8  2021    2021-08
# 1  Bandung   15    Tuesday      6  2021    2021-06
# 2  Bandung   19  Wednesday      5  2021    2021-05
# 3  Bandung    4  Wednesday      8  2021    2021-08
# 4  Bandung   12   Saturday      6  2021    2021-06

# %%
df_completed.loc[:,['total_quantity', 'total_amount','total_weight']].describe()
# Out:
#        total_quantity  total_amount  total_weight
# count    37011.000000  3.701100e+04  3.701100e+04
# mean        39.214171  2.279974e+04  6.038418e+03
# std         65.721626  1.861798e+05  2.325906e+04
# min          0.000000  0.000000e+00  0.000000e+00
# 25%          8.500000  2.350000e+02  5.540160e+02
# 50%         21.000000  2.960000e+02  2.148154e+03
# 75%         48.000000  1.143000e+03  5.780302e+03
# max       2450.000000  9.815420e+06  1.540000e+06

# %% [markdown]
# Here we can see the that:
# 1. Minimal total_quantity, total amount, and total weight are zero (make no sense).  Thus I'll filter the transaction that greater than 0.
# 2. Since the unit for total quantity is not the same, I'll skip this for now.
# 2. The median and mean for total amount and total weight are far apart. For instance, the median and average of total weight of customer orders are 2,500 gr and 6,149.6 gr respectively. This wide gap might occurs due to type of waste that user assign (some might assign plastics waste and some might assign electronic waste like pc)

# %%
# Distribution of total_amount and total_weight Before Filtering Out Zero Values

fig = go.Figure()
fig.add_trace(go.Box(y=df_completed['total_amount'], name='Total Amount (points)'))
fig.add_trace(go.Box(y=df_completed['total_weight'], name='Total Weight (grams)'))
fig.update_layout(title='Distribution of Total Amount and Total Weight')
pio.base_renderers.default = "browser"
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2a93b6f8-843c-4143-8b2f-558eedf384b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a93b6f8-843c-4143-8b2f-558eedf384b4")) {                    Plotly.newPlot(                        "2a93b6f8-843c-4143-8b2f-558eedf384b4",                        [{"name":"Total Amount (points)","y":[155.0,250.0,250.0,70.0,40.0,500.0,250.0,200.0,10.0,22.0,254.0,250.0,302.0,256.0,342.0,262.0,164.0,528.0,250.0,250.0,114.0,250.0,75.0,840.0,250.0,306.0,564.0,36.0,250.0,250.0,250.0,290.0,2850.0,10.0,1850.0,6700.0,
,5.3230099791384085,4.574710978503383,6.049733455231958,6.040254711277414,4.442651256490317,5.081404364984463,5.521460917862246,5.796057750765372,6.565264970035361,6.421622267806518,6.56244409369372,4.532599493153256,5.493061443340548,5.049856007249537,4.564348191467836,5.521460917862246,5.521460917862246,1.6094379124341003,9.489259158757807,6.63200177739563,7.24422751560335,5.973809611869261,5.10594547390058,5.752572638825633,5.521460917862246,5.19295685089021,4.007333185232471,5.683579767338681,4.8283137373023015,9.798127036878302,4.0943445622221,5.616771097666572,4.007333185232471,2.70805020110221,5.991464547107982,5.786897381366708,6.717804695023691,4.454347296253507,6.856461984594587,6.461468176353717,6.620073206530356,6.336825731146441,6.984716320118266,6.6052979209482015,4.007333185232471,5.556828061699537,6.016157159698354,4.465908118654584,6.040254711277414,4.634728988229636,5.521460917862246,5.521460917862246,5.521460917862246,9.53791600808964,5.703782474656201,5.8916442118257715,5.634789603169249,5.616771097666572,5.19295685089021,5.209486152841421,5.703782474656201,5.950642552587727,7.975908360165538,6.907755278982137,7.005789019253503,5.521460917862246,4.605170185988092,3.5553480614894135,3.5553480614894135,5.6131281063880705,6.0330862217988015,4.7535901911063645,5.19295685089021,6.289715570908998,5.521460917862246,6.163314804034641,5.393627546352362,5.43372200355424,6.102558594613569,5.521460917862246,7.955074273262696,5.703782474656201,6.501289670540389,5.771441123130016,3.6888794541139363,5.288267030694535,6.366470447731438,1.6094379124341003,6.184148890937483,5.521460917862246,3.6888794541139363,5.66988092298052,5.66988092298052,7.254884810077338,6.829793737512425,2.995732273553991,4.454347296253507,3.6888794541139363,5.3471075307174685,5.3471075307174685,2.995732273553991,4.820281565605037,4.605170185988092,4.553876891600541,5.075173815233827,3.912023005428146,6.648984550024776,5.940171252720432,5.697093486505405,4.787491742782046,4.6913478822291435,5.6058020662 ...

# %%
df_completed.loc[:,['total_amount','total_weight']][(df_completed.total_amount > 0) & (df_completed.total_weight > 0)].describe()
# Out:
#        total_amount  total_weight
# count  3.641700e+04  3.641700e+04
# mean   2.317162e+04  5.648780e+03
# std    1.876691e+05  2.034906e+04
# min    1.000000e+00  2.000000e-02
# 25%    2.500000e+02  5.400130e+02
# 50%    3.000000e+02  2.089029e+03
# 75%    1.200000e+03  5.736546e+03
# max    9.815420e+06  1.540000e+06

# %%
len(df_completed[df_completed['total_amount']==0]), len(df_completed[df_completed['total_weight']==0])
# Out:
# (593, 26)

# %% [markdown]
# What can we get from boxplot above:
# 1. There are many extreme values (outliers) for total amounts, and total weight. The cause might be due to type of waste customer assigned.
# 2. After performing log transformation total weight is normal-enough distributed.
# 3. Total amount and weight is right skewed distributed. It means that total points gained by user orders is mostly below the average point of 7,727.95

# %%
df_completed = df_completed[(df_completed['total_amount']>0) & (df_completed['total_weight']>0)]

# %%
# %store df_completed
# Out:
# Stored 'df_completed' (DataFrame)

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
